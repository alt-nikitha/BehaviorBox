# %%
import json
import pandas as pd

with open("/data/user_data/nsrikant/bbox_data/data/olmo_validation_texts.jsonl", "r") as f:
    lines = f.readlines()

records = []
for line in lines:
    data = json.loads(line)
    records.append(data)

df = pd.DataFrame.from_records(records)
print(df.shape)
df.head()
# Out:
# (1626, 3)
#   dataset                    id  \
# 0   c4_en  c4_en_part-0-00000_0
# 1   c4_en  c4_en_part-0-00000_1
# 2   c4_en  c4_en_part-0-00000_2
# 3   c4_en  c4_en_part-0-00000_3
# 4   c4_en  c4_en_part-0-00000_4
#
#                                                 text
# 0  As an Ex England International and current Cha...
# 1  izing freight demand, basic data are sought to...
# 2  .\nThis is an easy way to bring in more colors...
# 3  ulaire was posted June on this site by Sileka....
# 4   balloon, would it be that possible? Is on tha...
