# %%
with open("/home/nsrikant/BehaviorBoxNew/data/blimp_full.jsonl", "r") as fp:
    texts = fp.readlines()

# %%
texts[0]
# Out:
# '{"id": "wh_questions_subject_gap_long_distance_bad_62344", "text": "Jennifer didn\'t know what some actress that Helen praised won\'t criticize the restaurants.", "label": "bad", "split": "wh_questions_subject_gap_long_distance", "pair_id": 62344}\n'
